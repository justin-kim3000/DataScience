# %%
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import imdb
from sklearn.model_selection import train_test_split
from keras.models import Sequential

# %%
# # 파이참용
# import os
# os.environ['TF_CPP_MIN_LOG_LEVEL']

# %%
tf.keras.utils.set_random_seed(42)
tf.config.experimental.enable_op_determinism()

# %% [markdown]
# ## imdb - 영화리뷰
# ### target:1 - 긍정 / 0 - 부정

# %%
# num_words = 자주 사용되는 문장 선택
(train_input, train_target), (test_input, test_target) = imdb.load_data(num_words=300)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 1s 0us/step

# %%
train_input.shape
test_input.shape
# Out:
# (25000,)

# %%
len(train_input[0])
len(test_input[0])
# Out:
# 68

# %%
train_target[:10]
# Out:
# array([1, 0, 0, 1, 0, 0, 1, 0, 1, 0])

# %%
train_input, val_input, train_target, val_target = train_test_split(train_input,
                                                                    train_target,
                                                                    test_size=0.3,
                                                                    random_state=42)
lengths = np.array([len(x) for x in train_input])
len(lengths)
# Out:
# 17500

# %%
plt.hist(lengths)
plt.xlabel('lengths')
plt.ylabel('frequency')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
from keras.utils import pad_sequences, to_categorical

# %%
# 열을 특정 값으로 맞춤 / 부족할 경우 0으로 채움
train_seq = pad_sequences(train_input, maxlen=100)
val_seq = pad_sequences(val_input, maxlen=100)

print((train_seq[0]))
print((train_input[0]))
# Out:
# [ 40   4   2   7   4 274  33   4   2   2  11   4  65  21   2  41   2   8
#  216  46  11   2   2 139   4   2  15   2   5   2   2  11  68 139 295   9
#   82   2   5 283   8   2   5   2   2   2  17  73   4   2 156  82   2  68
#    2   2   5   4   2   2   4   2   2   7   4  65  10  10  13   2   2  14
#    2   7   4   2   2   2  48  25  28  24   2   4 274 159  95  25  70 106
#   14   2  17   6   2   2   8  14   2  65]
# [1, 13, 2, 2, 2, 2, 11, 2, 2, 5, 12, 2, 72, 19, 6, 2, 2, 133, 16, 6, 2, 2, 44, 6, 185, 2, 2, 8, 169, 119, 5, 2, 11, 4, 2, 211, 7, 2, 2, 14, 185, 255, 16, 2, 2, 6, 2, 5, 2, 109, 19, 6, 2, 2, 5, 80, 7, 41, 205, 41, 65, 63, 2, 2, 143, 2, 205, 2, 16, 199, 2, 5, 2, 10, 10, 17, 173, 7, 263, 2, 75, 296, 4, 2, 2, 7, 4, 65, 5, 12, 2, 72, 245, 4, 2, 201, 24, 64, 93, 4, 2, 8, 2, 283, 8, 2, 204, 2, 5, 4, 2, 7, 4, 65, 21, 4, 156, 37, 2, 4, 105, 71, 43, 87, 199, 2, 2, 2, 2, 5, 2, 2, 2, 2, 34, 4, 2, 7, 2, 2, 2, 4, 2, 7, 68, 105, 13, 2, 2, 259, 2, 11, 68, 2, 4, 85, 2, 7, 2, 11, 85, 2, 141, 17, 4, 2, 2, 2, 4, 2, 2, 5, 2, 2, 8, 2, 2, 2, 13, 135, 15, 2, 2, 266, 46, 23, 2, 88, 29, 2, 32, 134, 2, 11, 27, 2, 7, 2, 2, 2, 24, 64, 272, 40, 2, 2, 21, 59, 2, 2, 2, 21, 2, 5, 2, 2, 2, 59, 2, 11, 41, 2, 40, 4, 2, 7, 4, 274, 33, 4, 2, 2, 11, 4, 65, 21, 2, 41, 2, 8, 216, 46, 11, 2, 2, 139, 4, 2, 15, 2, 5, 2, 2, 11, 68, 139, 295, 9, 82, 2, 5, 283, 8, 2, 5, 2, 2, 2, 17, 73, 4, 2, 156, 82, 2, 68, 2, 2, 5, 4, 2, 2, 4, 2, 2, 7, 4, 65, 10, 10, 13, 2, 2, 14, 2, 7, 4, 2, 2, 2, 48, 25, 28, 24, 2, 4, 274, 159, 95, 25, 70, 106, 14, 2, 17, 6, 2, 2, 8, 14, 2, 65]

# %%
from keras.layers import Dense, SimpleRNN

# %%
model = Sequential()
# LSTM - GRU - 트렌스포머
model.add(SimpleRNN(8, input_shape=(100,300)))
# relu, sigmoid, adam
model.add(Dense(1, activation='sigmoid'))

# one hot encoding
train_oh = to_categorical(train_seq)
val_oh = to_categorical(val_seq)
val_oh.shape
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 8)                 2472
#
#  dense (Dense)               (None, 1)                 9
#
# =================================================================
# Total params: 2,481
# Trainable params: 2,481
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Root Mean Square Propagation
# 최근 time step 에서의 기울기는 많이 반영
# 먼 과거의 time step 기울기는 조금 반영
rmsprop = keras.optimizers.RMSprop(learning_rate=1e-4)
# 이진분류
model.compile(optimizer=rmsprop,
              loss='binary_crossentropy',
              # accuracy / f1score
              metrics=['accuracy'])

# %%
checkpoint_cb = keras.callbacks.ModelCheckpoint('best_simpleRNN.h5')
early_stopping_cb = keras.callbacks.EarlyStopping(patience=3, restore_best_weights=True)
# callback함수: 특정 이벤트(시그널)에 의해서 호출

# %%
fit_model = model.fit(train_oh, train_target,
                      batch_size=100,
                      epochs=100,
                      validation_data=(val_oh, val_target),
                      callbacks=[checkpoint_cb,
                                 early_stopping_cb])
# Out:
# Epoch 1/100
# 175/175 [==============================] - 11s 53ms/step - loss: 0.7014 - accuracy: 0.4988 - val_loss: 0.6977 - val_accuracy: 0.5108
# Epoch 2/100
# 175/175 [==============================] - 8s 47ms/step - loss: 0.6975 - accuracy: 0.5063 - val_loss: 0.6955 - val_accuracy: 0.5120
# Epoch 3/100
# 175/175 [==============================] - 8s 47ms/step - loss: 0.6947 - accuracy: 0.5142 - val_loss: 0.6937 - val_accuracy: 0.5215
# Epoch 4/100
# 175/175 [==============================] - 7s 40ms/step - loss: 0.6919 - accuracy: 0.5274 - val_loss: 0.6908 - val_accuracy: 0.5328
# Epoch 5/100
# 175/175 [==============================] - 8s 46ms/step - loss: 0.6871 - accuracy: 0.5488 - val_loss: 0.6855 - val_accuracy: 0.5595
# Epoch 6/100
# 175/175 [==============================] - 7s 40ms/step - loss: 0.6813 - accuracy: 0.5702 - val_loss: 0.6830 - val_accuracy: 0.5649
# Epoch 7/100
# 175/175 [==============================] - 8s 47ms/step - loss: 0.6776 - accuracy: 0.5797 - val_loss: 0.6797 - val_accuracy: 0.5760
# Epoch 8/100
# 175/175 [==============================] - 12s 66ms/step - loss: 0.6745 - accuracy: 0.5881 - val_loss: 0.6769 - val_accuracy: 0.5825
# Epoch 9/100
# 175/175 [==============================] - 7s 40ms/step - loss: 0.6706 - accuracy: 0.5996 - val_loss: 0.6752 - val_accuracy: 0.5853
# Epoch 10/100
# 175/175 [==============================] - 8s 48ms/step - loss: 0.6671 - accuracy: 0.6070 - val_loss: 0.6700 - val_accuracy: 0.5997
# Epoch 11/100
# 175/175 [==============================] - 9s 52ms/step - loss: 0.6629 - accuracy: 0.6165 - val_loss: 0.6675 - val_accuracy: 0.6028
# Epoch 12/100
# 175/175 [==============================] - 7s 40ms/step - loss: 0.6586 - accuracy: 0.6231 - val_loss: 0.6621 - val_accuracy: 0.6139
# Epoch 13/100
# 175/175 [==============================] - 10s 55ms/step - loss: 0.6540 - accuracy: 0.6327 - val_loss: 0.6585 - val_accuracy: 0.6177
# Epoch 14/100
# 175/175 [==============================] - 9s 51ms/step - loss: 0.6487 - accuracy: 0.6406 - val_loss: 0.6548 - val_accuracy: 0.6252
# Epoch 15/100
# 175/175 [==============================] - 7s 41ms/step - loss: 0.6435 - accuracy: 0.6479 - val_loss: 0.6510 - val_accuracy: 0.6307
# Epoch 16/100
# 175/175 [==============================] - 8s 46ms/step - loss: 0.6381 - accuracy: 0.6543 - val_loss: 0.6443 - val_accuracy: 0.6409
# Epoch 17/100
# 175/175 [==============================] - 8s 48ms/step - loss: 0.6328 - accuracy: 0.6617 - val_loss: 0.6398 - val_accuracy: 0.6464
# Epoch 18/100
# 175/175 [==============================] - 7s 40ms/step - loss: 0.6265 - accuracy: 0.6713 - val_loss: 0.6340 - val_accuracy: 0.6540
# Epoch 19/100
# 175/175 [==============================] - 8s 47ms/step - loss: 0.6206 - accuracy: 0.6779 - val_loss: 0.6274 - val_accuracy: 0.6627
# Epoch 20/100
# 175/175 [==============================] - 8s 47ms/step - loss: 0.6143 - accuracy: 0.6835 - val_loss: 0.6223 - val_accuracy: 0.6683
# Epoch 21/100
# 175/175 [==============================] - 8s 45ms/step - loss: 0.6070 - accuracy: 0.6935 - val_loss: 0.6168 - val_accuracy: 0.6720
# Epoch 22/100
# 175/175 [==============================] - 8s 46ms/step - loss: 0.6005 - accuracy: 0.6990 - val_loss: 0.6091 - val_accuracy: 0.6813
# Epoch 23/100
# 175/175 [==============================] - 7s 40ms/step - loss: 0.5942 - accuracy: 0.7041 - val_loss: 0.6028 - val_accuracy: 0.6899
# Epoch 24/100
# 175/175 [==============================] - 8s 47ms/step - loss: 0.5877 - accuracy: 0.7102 - val_loss: 0.5967 - val_accuracy: 0.6921
# Epoch 25/100
# 175/175 [==============================] - 7s 40ms/step - loss: 0.5819 - accuracy: 0.7141 - val_loss: 0.5909 - val_accuracy: 0.6992
# Epoch 26/100
# 175/175 [==============================] - 8s 46ms/step - loss: 0.5768 - accuracy: 0.7184 - val_loss: 0.5855 - val_accuracy: 0.7027
# Epoch 27/100
# 175/175 [==============================] - 8s 48ms/step - loss: 0.5708 - accuracy: 0.7230 - val_loss: 0.5828 - val_accuracy: 0.7024
# Epoch 28/100
# 175/175 [==============================] - 8s 47ms/step - loss: 0.5654 - accuracy: 0.7273 - val_loss: 0.5744 - val_accuracy: 0.7109
# Epoch 29/100
# 175/175 [==============================] - 8s 47ms/step - loss: 0.5598 - accuracy: 0.7316 - val_loss: 0.5696 - val_accuracy: 0.7151
# Epoch 30/100
# 175/175 [==============================] - 7s 42ms/step - loss: 0.5548 - accuracy: 0.7350 - val_loss: 0.5683 - val_accuracy: 0.7155
# Epoch 31/100
# 175/175 [==============================] - 8s 43ms/step - loss: 0.5511 - accuracy: 0.7371 - val_loss: 0.5623 - val_accuracy: 0.7196
# Epoch 32/100
# 175/175 [==============================] - 8s 46ms/step - loss: 0.5458 - accuracy: 0.7400 - val_loss: 0.5565 - val_accuracy: 0.7232
# Epoch 33/100
# 175/175 [==============================] - 7s 39ms/step - loss: 0.5418 - accuracy: 0.7405 - val_loss: 0.5533 - val_accuracy: 0.7260
# Epoch 34/100
# 175/175 [==============================] - 8s 46ms/step - loss: 0.5384 - accuracy: 0.7442 - val_loss: 0.5498 - val_accuracy: 0.7299
# Epoch 35/100
# 175/175 [==============================] - 7s 39ms/step - loss: 0.5346 - accuracy: 0.7470 - val_loss: 0.5482 - val_accuracy: 0.7257
# Epoch 36/100
# 175/175 [==============================] - 9s 54ms/step - loss: 0.5313 - accuracy: 0.7471 - val_loss: 0.5443 - val_accuracy: 0.7325
# Epoch 37/100
# 175/175 [==============================] - 8s 46ms/step - loss: 0.5287 - accuracy: 0.7497 - val_loss: 0.5424 - val_accuracy: 0.7328
# Epoch 38/100
# 175/175 [==============================] - 8s 47ms/step - loss: 0.5253 - accuracy: 0.7529 - val_loss: 0.5397 - val_accuracy: 0.7325
# Epoch 39/100
# 175/175 [==============================] - 8s 47ms/step - loss: 0.5225 - accuracy: 0.7523 - val_loss: 0.5383 - val_accuracy: 0.7336
# Epoch 40/100
# 175/175 [==============================] - 9s 49ms/step - loss: 0.5200 - accuracy: 0.7557 - val_loss: 0.5409 - val_accuracy: 0.7343
# Epoch 41/100
# 175/175 [==============================] - 7s 40ms/step - loss: 0.5180 - accuracy: 0.7568 - val_loss: 0.5342 - val_accuracy: 0.7371
# Epoch 42/100
# 175/175 [==============================] - 9s 54ms/step - loss: 0.5156 - accuracy: 0.7582 - val_loss: 0.5323 - val_accuracy: 0.7395
# Epoch 43/100
# 175/175 [==============================] - 8s 47ms/step - loss: 0.5137 - accuracy: 0.7577 - val_loss: 0.5311 - val_accuracy: 0.7381
# Epoch 44/100
# 175/175 [==============================] - 7s 39ms/step - loss: 0.5117 - accuracy: 0.7593 - val_loss: 0.5303 - val_accuracy: 0.7408
# Epoch 45/100
# 175/175 [==============================] - 8s 47ms/step - loss: 0.5101 - accuracy: 0.7591 - val_loss: 0.5288 - val_accuracy: 0.7397
# Epoch 46/100
# 175/175 [==============================] - 8s 47ms/step - loss: 0.5084 - accuracy: 0.7622 - val_loss: 0.5281 - val_accuracy: 0.7433
# Epoch 47/100
# 175/175 [==============================] - 8s 44ms/step - loss: 0.5068 - accuracy: 0.7614 - val_loss: 0.5275 - val_accuracy: 0.7413
# Epoch 48/100
# 175/175 [==============================] - 9s 52ms/step - loss: 0.5056 - accuracy: 0.7633 - val_loss: 0.5263 - val_accuracy: 0.7419
# Epoch 49/100
# 175/175 [==============================] - 7s 40ms/step - loss: 0.5037 - accuracy: 0.7649 - val_loss: 0.5257 - val_accuracy: 0.7427
# Epoch 50/100
# 175/175 [==============================] - 8s 47ms/step - loss: 0.5033 - accuracy: 0.7637 - val_loss: 0.5254 - val_accuracy: 0.7420
# Epoch 51/100
# 175/175 [==============================] - 7s 43ms/step - loss: 0.5017 - accuracy: 0.7668 - val_loss: 0.5263 - val_accuracy: 0.7419
# Epoch 52/100
# 175/175 [==============================] - 9s 49ms/step - loss: 0.5006 - accuracy: 0.7683 - val_loss: 0.5287 - val_accuracy: 0.7391
# Epoch 53/100
# 175/175 [==============================] - 8s 46ms/step - loss: 0.5003 - accuracy: 0.7658 - val_loss: 0.5238 - val_accuracy: 0.7441
# Epoch 54/100
# 175/175 [==============================] - 7s 40ms/step - loss: 0.4984 - accuracy: 0.7690 - val_loss: 0.5231 - val_accuracy: 0.7420
# Epoch 55/100
# 175/175 [==============================] - 8s 47ms/step - loss: 0.4979 - accuracy: 0.7697 - val_loss: 0.5223 - val_accuracy: 0.7397
# Epoch 56/100
# 175/175 [==============================] - 8s 44ms/step - loss: 0.4967 - accuracy: 0.7689 - val_loss: 0.5222 - val_accuracy: 0.7399
# Epoch 57/100
# 175/175 [==============================] - 7s 40ms/step - loss: 0.4958 - accuracy: 0.7697 - val_loss: 0.5218 - val_accuracy: 0.7408
# Epoch 58/100
# 175/175 [==============================] - 8s 47ms/step - loss: 0.4948 - accuracy: 0.7711 - val_loss: 0.5216 - val_accuracy: 0.7428
# Epoch 59/100
# 175/175 [==============================] - 8s 47ms/step - loss: 0.4941 - accuracy: 0.7703 - val_loss: 0.5200 - val_accuracy: 0.7415
# Epoch 60/100
# 175/175 [==============================] - 8s 46ms/step - loss: 0.4934 - accuracy: 0.7711 - val_loss: 0.5225 - val_accuracy: 0.7417
# Epoch 61/100
# 175/175 [==============================] - 8s 46ms/step - loss: 0.4929 - accuracy: 0.7725 - val_loss: 0.5202 - val_accuracy: 0.7432
# Epoch 62/100
# 175/175 [==============================] - 7s 40ms/step - loss: 0.4919 - accuracy: 0.7723 - val_loss: 0.5212 - val_accuracy: 0.7421

# %%
plt.plot(fit_model.history['loss'])
plt.plot(fit_model.history['val_loss'])
plt.xlabel=('epochs')
plt.ylabel=('loss')
plt.legend(['train','val'])
