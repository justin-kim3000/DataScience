# %%
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential, Model
from keras.layers import Input, Dense

# %%
tf.__version__
# Out:
# '2.11.0'

# %% [markdown]
# ## 신경망 구성
# ### input layer -> hidden layer -> output layer

# %%
# shape -> 
input_layer = Input(shape=(32,32,1))

# %%
# 은닉층(렐루 -> ReLU 계층 사용)
x = Dense(units=100, activation='relu')(input_layer)
# 2번째 은닉층
x = Dense(units=50, activation='relu')(x)
# 출력층
outuput_layer = Dense(units=5, activation='softmax')(x)

# %%
model = Model(input_layer, outuput_layer)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 1)]       0
#
#  dense (Dense)               (None, 32, 32, 100)       200
#
#  dense_1 (Dense)             (None, 32, 32, 50)        5050
#
#  dense_2 (Dense)             (None, 32, 32, 5)         255
#
# =================================================================
# Total params: 5,505
# Trainable params: 5,505
# Non-trainable params: 0
# _________________________________________________________________
