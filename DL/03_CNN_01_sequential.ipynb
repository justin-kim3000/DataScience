# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# seed 값 고정
tf.keras.utils.set_random_seed(42)
tf.config.experimental.enable_op_determinism()

# %%
fa_mnist = tf.keras.datasets.fashion_mnist
(X_train, y_train), (X_test, y_test) = fa_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 2s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
plt.imshow(X_train[0])

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
model = tf.keras.models.Sequential()
# 입력층
model.add(tf.keras.layers.Flatten(input_shape=(28, 28)))
model.add(tf.keras.layers.Dense(512, activation='relu'))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(512, activation='relu'))
# 출력층
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_3 (Dense)             (None, 512)               401920
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_4 (Dense)             (None, 512)               262656
#
#  dense_5 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 669,706
# Trainable params: 669,706
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs = 50, batch_size= 1200)
# Out:
# Epoch 1/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.1064 - accuracy: 0.9598
# Epoch 2/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0945 - accuracy: 0.9637
# Epoch 3/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0958 - accuracy: 0.9638
# Epoch 4/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0927 - accuracy: 0.9647
# Epoch 5/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0945 - accuracy: 0.9641
# Epoch 6/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0863 - accuracy: 0.9673
# Epoch 7/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0865 - accuracy: 0.9674
# Epoch 8/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0854 - accuracy: 0.9678
# Epoch 9/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0847 - accuracy: 0.9678
# Epoch 10/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0846 - accuracy: 0.9685
# Epoch 11/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0851 - accuracy: 0.9676
# Epoch 12/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0827 - accuracy: 0.9681
# Epoch 13/50
# 50/50 [==============================] - 0s 8ms/step - loss: 0.0850 - accuracy: 0.9675
# Epoch 14/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0795 - accuracy: 0.9698
# Epoch 15/50
# 50/50 [==============================] - 0s 8ms/step - loss: 0.0803 - accuracy: 0.9697
# Epoch 16/50
# 50/50 [==============================] - 0s 8ms/step - loss: 0.0813 - accuracy: 0.9696
# Epoch 17/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0823 - accuracy: 0.9685
# Epoch 18/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0815 - accuracy: 0.9687
# Epoch 19/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0766 - accuracy: 0.9707
# Epoch 20/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0799 - accuracy: 0.9691
# Epoch 21/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0773 - accuracy: 0.9703
# Epoch 22/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0747 - accuracy: 0.9719
# Epoch 23/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0733 - accuracy: 0.9719
# Epoch 24/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0720 - accuracy: 0.9731
# Epoch 25/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0689 - accuracy: 0.9742
# Epoch 26/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0711 - accuracy: 0.9730
# Epoch 27/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0680 - accuracy: 0.9741
# Epoch 28/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0669 - accuracy: 0.9748
# Epoch 29/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0715 - accuracy: 0.9739
# Epoch 30/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0639 - accuracy: 0.9761
# Epoch 31/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0649 - accuracy: 0.9756
# Epoch 32/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0660 - accuracy: 0.9749
# Epoch 33/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0691 - accuracy: 0.9741
# Epoch 34/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0717 - accuracy: 0.9725
# Epoch 35/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0689 - accuracy: 0.9738
# Epoch 36/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0668 - accuracy: 0.9740
# Epoch 37/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0597 - accuracy: 0.9776
# Epoch 38/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0607 - accuracy: 0.9769
# Epoch 39/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0576 - accuracy: 0.9785
# Epoch 40/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0606 - accuracy: 0.9770
# Epoch 41/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0660 - accuracy: 0.9753
# Epoch 42/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0630 - accuracy: 0.9757
# Epoch 43/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0616 - accuracy: 0.9762
# Epoch 44/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0575 - accuracy: 0.9779
# Epoch 45/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0577 - accuracy: 0.9780
# Epoch 46/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0583 - accuracy: 0.9775
# Epoch 47/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0610 - accuracy: 0.9766
# Epoch 48/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0536 - accuracy: 0.9798
# Epoch 49/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0558 - accuracy: 0.9791
# Epoch 50/50
# 50/50 [==============================] - 0s 8ms/step - loss: 0.0566 - accuracy: 0.9785

# %%
model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4787 - accuracy: 0.8994
# [0.47870782017707825, 0.899399995803833]
