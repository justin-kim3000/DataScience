# %%
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import imdb
from sklearn.model_selection import train_test_split
from keras.models import Sequential

# %%
# # 파이참용
# import os
# os.environ['TF_CPP_MIN_LOG_LEVEL']

# %%
tf.keras.utils.set_random_seed(42)
tf.config.experimental.enable_op_determinism()

# %% [markdown]
# ## imdb - 영화리뷰
# ### target:1 - 긍정 / 0 - 부정

# %%
# num_words = 자주 사용되는 문장 선택
(train_input, train_target), (test_input, test_target) = imdb.load_data(num_words=500)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 1s 0us/step

# %%
train_input.shape
test_input.shape
# Out:
# (25000,)

# %%
len(train_input[0])
len(test_input[0])
# Out:
# 68

# %%
train_target[:10]
# Out:
# array([1, 0, 0, 1, 0, 0, 1, 0, 1, 0])

# %%
train_input, val_input, train_target, val_target = train_test_split(train_input,
                                                                    train_target,
                                                                    test_size=0.3,
                                                                    random_state=42)
lengths = np.array([len(x) for x in train_input])
len(lengths)
# Out:
# 17500

# %%
plt.hist(lengths)
plt.xlabel('lengths')
plt.ylabel('frequency')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
from keras.utils import pad_sequences, to_categorical

# %%
# 열을 특정 값으로 맞춤 / 부족할 경우 0으로 채움
train_seq = pad_sequences(train_input, maxlen=100)
val_seq = pad_sequences(val_input, maxlen=100)

print((train_seq[0]))
print((train_input[0]))
# Out:
# [ 40   4   2   7   4 274  33   4   2 388  11   4  65  21   2  41   2   8
#  216  46  11   2   2 139   4   2  15   2   5   2   2  11  68 139 295   9
#   82   2   5 283   8   2   5   2   2   2  17  73   4   2 156  82   2  68
#    2   2   5   4   2   2   4   2   2   7   4  65  10  10  13   2 386  14
#  310   7   4 356   2   2  48  25  28  24 332   4 274 159  95  25  70 106
#   14 365  17   6   2   2   8  14 307  65]
# [1, 13, 2, 2, 2, 2, 11, 312, 396, 5, 12, 317, 72, 19, 6, 2, 2, 133, 16, 6, 307, 2, 44, 6, 185, 2, 2, 8, 169, 119, 5, 2, 11, 4, 465, 211, 7, 2, 2, 14, 185, 255, 16, 2, 2, 6, 338, 5, 2, 109, 19, 6, 2, 330, 5, 80, 7, 41, 205, 41, 65, 63, 2, 2, 143, 2, 205, 2, 16, 199, 2, 5, 2, 10, 10, 17, 173, 7, 263, 2, 75, 296, 4, 2, 2, 7, 4, 65, 5, 12, 2, 72, 245, 4, 2, 201, 24, 64, 93, 4, 2, 8, 2, 283, 8, 2, 204, 2, 5, 4, 2, 7, 4, 65, 21, 4, 156, 37, 2, 4, 105, 71, 43, 87, 199, 2, 2, 2, 2, 5, 2, 2, 2, 2, 34, 4, 403, 7, 2, 2, 2, 4, 2, 7, 68, 105, 13, 2, 2, 259, 334, 11, 68, 2, 4, 85, 354, 7, 2, 11, 85, 2, 141, 17, 4, 2, 310, 2, 4, 2, 2, 5, 2, 2, 8, 2, 2, 2, 13, 135, 15, 2, 2, 266, 46, 23, 350, 88, 29, 2, 32, 134, 2, 11, 27, 2, 7, 2, 2, 2, 24, 64, 272, 40, 2, 2, 21, 59, 2, 2, 2, 21, 2, 5, 2, 2, 2, 59, 2, 11, 41, 2, 40, 4, 2, 7, 4, 274, 33, 4, 2, 388, 11, 4, 65, 21, 2, 41, 2, 8, 216, 46, 11, 2, 2, 139, 4, 2, 15, 2, 5, 2, 2, 11, 68, 139, 295, 9, 82, 2, 5, 283, 8, 2, 5, 2, 2, 2, 17, 73, 4, 2, 156, 82, 2, 68, 2, 2, 5, 4, 2, 2, 4, 2, 2, 7, 4, 65, 10, 10, 13, 2, 386, 14, 310, 7, 4, 356, 2, 2, 48, 25, 28, 24, 332, 4, 274, 159, 95, 25, 70, 106, 14, 365, 17, 6, 2, 2, 8, 14, 307, 65]

# %%
from keras.layers import Dense, SimpleRNN

# %%
model = Sequential()
# LSTM - GRU - 트렌스포머
model.add(SimpleRNN(8, input_shape=(100,500)))
# relu, sigmoid, adam
model.add(Dense(1, activation='sigmoid'))

# one hot encoding
train_oh = to_categorical(train_seq)
val_oh = to_categorical(val_seq)
val_oh.shape
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 8)                 4072
#
#  dense (Dense)               (None, 1)                 9
#
# =================================================================
# Total params: 4,081
# Trainable params: 4,081
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Root Mean Square Propagation
# 최근 time step 에서의 기울기는 많이 반영
# 먼 과거의 time step 기울기는 조금 반영
rmsprop = keras.optimizers.RMSprop(learning_rate=1e-4)
# 이진분류
model.compile(optimizer=rmsprop,
              loss='binary_crossentropy',
              # accuracy / f1score
              metrics=['accuracy'])

# %%
checkpoint_cb = keras.callbacks.ModelCheckpoint('best_simpleRNN.h5')
early_stopping_cb = keras.callbacks.EarlyStopping(patience=3, restore_best_weights=True)
# callback함수: 특정 이벤트(시그널)에 의해서 호출

# %%
fit_model = model.fit(train_oh, train_target,
                      batch_size=100,
                      epochs=100,
                      validation_data=(val_oh, val_target),
                      callbacks=[checkpoint_cb,
                                 early_stopping_cb])
# Out:
# Epoch 1/100
# 175/175 [==============================] - 15s 61ms/step - loss: 0.6977 - accuracy: 0.5030 - val_loss: 0.6939 - val_accuracy: 0.5176
# Epoch 2/100
# 175/175 [==============================] - 6s 35ms/step - loss: 0.6920 - accuracy: 0.5231 - val_loss: 0.6889 - val_accuracy: 0.5412
# Epoch 3/100
# 175/175 [==============================] - 6s 34ms/step - loss: 0.6845 - accuracy: 0.5550 - val_loss: 0.6818 - val_accuracy: 0.5717
# Epoch 4/100
# 175/175 [==============================] - 6s 35ms/step - loss: 0.6777 - accuracy: 0.5802 - val_loss: 0.6774 - val_accuracy: 0.5851
# Epoch 5/100
# 175/175 [==============================] - 6s 34ms/step - loss: 0.6724 - accuracy: 0.5953 - val_loss: 0.6731 - val_accuracy: 0.5947
# Epoch 6/100
# 175/175 [==============================] - 6s 35ms/step - loss: 0.6670 - accuracy: 0.6095 - val_loss: 0.6680 - val_accuracy: 0.6068
# Epoch 7/100
# 175/175 [==============================] - 6s 34ms/step - loss: 0.6605 - accuracy: 0.6234 - val_loss: 0.6626 - val_accuracy: 0.6189
# Epoch 8/100
# 175/175 [==============================] - 7s 37ms/step - loss: 0.6535 - accuracy: 0.6400 - val_loss: 0.6565 - val_accuracy: 0.6283
# Epoch 9/100
# 175/175 [==============================] - 6s 34ms/step - loss: 0.6457 - accuracy: 0.6536 - val_loss: 0.6496 - val_accuracy: 0.6393
# Epoch 10/100
# 175/175 [==============================] - 6s 35ms/step - loss: 0.6370 - accuracy: 0.6658 - val_loss: 0.6411 - val_accuracy: 0.6552
# Epoch 11/100
# 175/175 [==============================] - 6s 35ms/step - loss: 0.6275 - accuracy: 0.6796 - val_loss: 0.6322 - val_accuracy: 0.6645
# Epoch 12/100
# 175/175 [==============================] - 6s 36ms/step - loss: 0.6172 - accuracy: 0.6949 - val_loss: 0.6226 - val_accuracy: 0.6795
# Epoch 13/100
# 175/175 [==============================] - 7s 37ms/step - loss: 0.6074 - accuracy: 0.7059 - val_loss: 0.6128 - val_accuracy: 0.6927
# Epoch 14/100
# 175/175 [==============================] - 6s 36ms/step - loss: 0.5966 - accuracy: 0.7167 - val_loss: 0.6029 - val_accuracy: 0.7011
# Epoch 15/100
# 175/175 [==============================] - 6s 35ms/step - loss: 0.5868 - accuracy: 0.7246 - val_loss: 0.5937 - val_accuracy: 0.7129
# Epoch 16/100
# 175/175 [==============================] - 6s 33ms/step - loss: 0.5766 - accuracy: 0.7326 - val_loss: 0.5846 - val_accuracy: 0.7168
# Epoch 17/100
# 175/175 [==============================] - 6s 35ms/step - loss: 0.5664 - accuracy: 0.7420 - val_loss: 0.5766 - val_accuracy: 0.7204
# Epoch 18/100
# 175/175 [==============================] - 6s 34ms/step - loss: 0.5566 - accuracy: 0.7499 - val_loss: 0.5671 - val_accuracy: 0.7285
# Epoch 19/100
# 175/175 [==============================] - 6s 35ms/step - loss: 0.5472 - accuracy: 0.7540 - val_loss: 0.5587 - val_accuracy: 0.7335
# Epoch 20/100
# 175/175 [==============================] - 6s 34ms/step - loss: 0.5382 - accuracy: 0.7593 - val_loss: 0.5517 - val_accuracy: 0.7349
# Epoch 21/100
# 175/175 [==============================] - 6s 35ms/step - loss: 0.5296 - accuracy: 0.7644 - val_loss: 0.5453 - val_accuracy: 0.7368
# Epoch 22/100
# 175/175 [==============================] - 6s 34ms/step - loss: 0.5219 - accuracy: 0.7665 - val_loss: 0.5368 - val_accuracy: 0.7463
# Epoch 23/100
# 175/175 [==============================] - 6s 35ms/step - loss: 0.5136 - accuracy: 0.7718 - val_loss: 0.5292 - val_accuracy: 0.7531
# Epoch 24/100
# 175/175 [==============================] - 6s 34ms/step - loss: 0.5065 - accuracy: 0.7745 - val_loss: 0.5239 - val_accuracy: 0.7532
# Epoch 25/100
# 175/175 [==============================] - 6s 35ms/step - loss: 0.4995 - accuracy: 0.7793 - val_loss: 0.5221 - val_accuracy: 0.7524
# Epoch 26/100
# 175/175 [==============================] - 8s 44ms/step - loss: 0.4926 - accuracy: 0.7826 - val_loss: 0.5121 - val_accuracy: 0.7615
# Epoch 27/100
# 175/175 [==============================] - 8s 43ms/step - loss: 0.4863 - accuracy: 0.7861 - val_loss: 0.5070 - val_accuracy: 0.7655
# Epoch 28/100
# 175/175 [==============================] - 7s 41ms/step - loss: 0.4802 - accuracy: 0.7886 - val_loss: 0.5013 - val_accuracy: 0.7665
# Epoch 29/100
# 175/175 [==============================] - 6s 34ms/step - loss: 0.4751 - accuracy: 0.7907 - val_loss: 0.4967 - val_accuracy: 0.7701
# Epoch 30/100
# 175/175 [==============================] - 6s 35ms/step - loss: 0.4703 - accuracy: 0.7949 - val_loss: 0.4973 - val_accuracy: 0.7676
# Epoch 31/100
# 175/175 [==============================] - 6s 34ms/step - loss: 0.4659 - accuracy: 0.7963 - val_loss: 0.4898 - val_accuracy: 0.7733
# Epoch 32/100
# 175/175 [==============================] - 7s 39ms/step - loss: 0.4615 - accuracy: 0.7979 - val_loss: 0.4872 - val_accuracy: 0.7712
# Epoch 33/100
# 175/175 [==============================] - 7s 39ms/step - loss: 0.4574 - accuracy: 0.7994 - val_loss: 0.4834 - val_accuracy: 0.7752
# Epoch 34/100
# 175/175 [==============================] - 6s 35ms/step - loss: 0.4545 - accuracy: 0.8005 - val_loss: 0.4815 - val_accuracy: 0.7756
# Epoch 35/100
# 175/175 [==============================] - 6s 34ms/step - loss: 0.4504 - accuracy: 0.8028 - val_loss: 0.4809 - val_accuracy: 0.7768
# Epoch 36/100
# 175/175 [==============================] - 6s 35ms/step - loss: 0.4474 - accuracy: 0.8034 - val_loss: 0.4762 - val_accuracy: 0.7791
# Epoch 37/100
# 175/175 [==============================] - 6s 35ms/step - loss: 0.4443 - accuracy: 0.8047 - val_loss: 0.4732 - val_accuracy: 0.7813
# Epoch 38/100
# 175/175 [==============================] - 6s 35ms/step - loss: 0.4415 - accuracy: 0.8068 - val_loss: 0.4727 - val_accuracy: 0.7789
# Epoch 39/100
# 175/175 [==============================] - 6s 35ms/step - loss: 0.4394 - accuracy: 0.8080 - val_loss: 0.4709 - val_accuracy: 0.7821
# Epoch 40/100
# 175/175 [==============================] - 6s 34ms/step - loss: 0.4370 - accuracy: 0.8093 - val_loss: 0.4694 - val_accuracy: 0.7808
# Epoch 41/100
# 175/175 [==============================] - 6s 34ms/step - loss: 0.4339 - accuracy: 0.8101 - val_loss: 0.4680 - val_accuracy: 0.7833
# Epoch 42/100
# 175/175 [==============================] - 6s 34ms/step - loss: 0.4322 - accuracy: 0.8107 - val_loss: 0.4648 - val_accuracy: 0.7847
# Epoch 43/100
# 175/175 [==============================] - 6s 37ms/step - loss: 0.4302 - accuracy: 0.8101 - val_loss: 0.4644 - val_accuracy: 0.7833
# Epoch 44/100
# 175/175 [==============================] - 6s 34ms/step - loss: 0.4284 - accuracy: 0.8115 - val_loss: 0.4673 - val_accuracy: 0.7843
# Epoch 45/100
# 175/175 [==============================] - 6s 35ms/step - loss: 0.4267 - accuracy: 0.8116 - val_loss: 0.4626 - val_accuracy: 0.7855
# Epoch 46/100
# 175/175 [==============================] - 6s 34ms/step - loss: 0.4245 - accuracy: 0.8130 - val_loss: 0.4606 - val_accuracy: 0.7872
# Epoch 47/100
# 175/175 [==============================] - 6s 35ms/step - loss: 0.4231 - accuracy: 0.8125 - val_loss: 0.4612 - val_accuracy: 0.7861
# Epoch 48/100
# 175/175 [==============================] - 6s 34ms/step - loss: 0.4214 - accuracy: 0.8143 - val_loss: 0.4624 - val_accuracy: 0.7837
# Epoch 49/100
# 175/175 [==============================] - 6s 35ms/step - loss: 0.4200 - accuracy: 0.8150 - val_loss: 0.4615 - val_accuracy: 0.7853

# %%
plt.plot(fit_model.history['loss'])
plt.plot(fit_model.history['val_loss'])
plt.xlabel=('epochs')
plt.ylabel=('loss')
plt.legend(['train','val'])
