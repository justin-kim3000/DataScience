# %%
import requests as requests
from bs4 import BeautifulSoup

# %%
# 네이버 뉴스 속보
URL ='https://news.naver.com/main/list.nhn'
res = requests.get(URL, headers = {'User-Agent':'Mozilla/5.0'})

# %%
html = res.text

# %%
soup = BeautifulSoup(html, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE HTML>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="600" http-equiv="refresh">
# <meta content="width=1106" name="viewport">
# <meta content="언론사별 속보 뉴스" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://news.naver.com/main/list.naver?mode=LSD&amp;mid=sec&amp;sid=" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" property="og:image">
# <meta content="언론사별 속보 뉴스를 제공합니다." property="og:description"/>
# <meta content="네이버" property="og:article:author">
# <meta content="summary" name="twitter:card"/>
# <meta content="언론사별 속보 뉴스" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="네이버 뉴스" name="twitter:creator"/>
# ...

# %%
for i in soup.select('span[class=lede]'):
    print(i)

    #print(i.text.strip())
# Out:
# <span class="lede">유튜브 채널 ‘워크맨2’를 진행하는 방송인 장성규가 현대트랜시스의 시트 연구소를 찾았다. 현대트랜시스는 16일 ‘워크맨2 11화 …</span>
# <span class="lede">세종시의 한 아파트단지 입주자대표회의가 택배기사에게 승강기(엘리베이터) 사용료를 부과는 방안을 추진하다 논란 끝에 철회했다. 지 …</span>
# <span class="lede">김창원 경인교육대학교 총장이 오는 18일 오후 3시에 열리는 전국교원양성대학교 총장협의회(교총협)의 '교원양성체제 발전을 위한  …</span>
# <span class="lede">정부가 2030년까지 중견기업 1만 개를 육성하고 수출액 2000억 달러(약 246조 원)를 달성한다는 목표를 세웠다. 이를 위 …</span>
# <span class="lede">자생한방병원 척추관절연구소 하인혁 소장이 서울 중구 프레지던트 호텔에서 열린 ‘제21회 대한한의학회 학술대상’에서 금상을 수상했 …</span>
# <span class="lede">16일 597억원 투자 협약, 고용효과 130명 기대 수소 튜브 트레일러를 생산하는 수소 전문기업인 ㈜에테르씨티가 전북 완주군  …</span>
# <span class="lede">조성렬 전 주오사카 총영사는 최근 정부가 일제 강제동원 피해자 배상 문제를 일본 기업이 아닌 제3자 변제 방식으로 해결하려는 데 …</span>
# <span class="lede">미국 뉴욕 증시가 주요 은행들을 시작으로 본격적인 4분기 실적시즌에 돌입한 가운데, 경기둔화 전망 속에 상장사들의 이익 전망이  …</span>
# <span class="lede">인천 월미바다열차 운행이 임시 중단된다. 인천교통공사는 월미바다열차의 2023년 법정 정기검사 및 안전을 위한 재정비 시행으로  …</span>
# ...

# %%
# 네이버 영화 조회 순위
URL = 'https://movie.naver.com/movie/sdb/rank/rmovie.nhn'
res = requests.get(URL, headers = {'User-Agent':'Mozilla/5.0'})
html = res.text
soup = BeautifulSoup(html, 'html.parser')
rank = 1
for i in soup.select('div[class=tit3]'):
    
    print(str(rank)+". " + i.text.strip())
    rank += 1
# Out:
# 1. 더 퍼스트 슬램덩크
# 2. 아바타: 물의 길
# 3. 영웅
# 4. 스위치
# 5. 젠틀맨
# 6. 유령
# 7. 교섭
# 8. 강남좀비
# 9. 장화신은 고양이: 끝내주는 모험
# 10. 올빼미
# 11. 10일간의 애인
# 12. 3000년의 기다림
# 13. 문맨
# 14. 오늘 밤, 세계에서 이 사랑이 사라진다 해도
# 15. 메간
# 16. 솔캠
# 17. 시간을 꿈꾸는 소녀
# 18. 헤어질 결심
# 19. 해시태그 시그네
# 20. 라일 라일 크로커다일
# 21. 별 볼일 없는 인생
# 22. 앤트맨과 와스프: 퀀텀매니아
# 23. 유랑의 달
# 24. 프린스 챠밍
# 25. 압꾸정
# 26. 바빌론
# 27. 더 메뉴
# 28. 에브리씽 에브리웨어 올 앳 원스
# 29. 상견니
# 30. 늑대사냥
# 31. 공조2: 인터내셔날
# 32. 그 겨울, 나는
# 33. 페일 블루 아이
# 34. 극장판 카케구루이
# 35. B컷
# 36. 오펜하이머
# 37. 마리앙투아네트
# 38. 신비아파트 극장판 차원도깨비와 7개의 세계
# 39. 살수
# 40. 보스 베이비 2
# 41. 타이타닉: 25주년
# 42. 탑건: 매버릭
# 43. 나는 마을 방과후 교사입니다
# 44. 마루이 비디오
# 45. 패닉 런
# 46. 더 파벨먼스
# 47. 매복
# 48. 헌트
# 49. 캐리와 슈퍼콜라
# 50. 엄마의 땅: 그리샤와 숲의 주인

# %%
# 네이버 영화 평점 순위
URL = 'https://movie.naver.com/movie/sdb/rank/rmovie.naver?sel=cur&date=20230115'
res = requests.get(URL, headers = {'User-Agent':'Mozilla/5.0'})
html = res.text
soup = BeautifulSoup(html, 'html.parser')
rank = 1
movie = []
rank_li = []

for i in soup.select('div[class=tit5]'):
    
    print(str(rank)+". " + i.text.strip())
    rank += 1
# Out:
# 1. 더 퍼스트 슬램덩크
# 2. 올빼미
# 3. 시네마 천국
# 4. 말할 수 없는 비밀
# 5. 극장판 주술회전 0
# 6. 킹 오브 프리즘
# 7. 코다
# 8. 러브레터
# 9. 킹 오브 프리즘 프라이드 더 히어로
# 10. 탄생
# 11. 비긴 어게인
# 12. 타오르는 여인의 초상
# 13. 영웅
# 14. 더 파더
# 15. 윤희에게
# 16. 장화신은 고양이: 끝내주는 모험
# 17. 너의 이름은.
# 18. 벌새
# 19. 마미
# 20. 헤어질 결심
# 21. 아바타: 물의 길
# 22. 라라랜드
# 23. 오늘 밤, 세계에서 이 사랑이 사라진다 해도
# 24. 양자경의 더 모든 날 모든 순간
# 25. 스위치
# 26. 레토
# 27. 드라이브 마이 카
# 28. 라 비 앙 로즈
# 29. 패터슨
# 30. 에브리씽 에브리웨어 올 앳 원스
# 31. 거북이는 의외로 빨리 헤엄친다
# 32. 애프터 양
# 33. 우연과 상상
# 34. 본즈 앤 올
# 35. 원더풀 라이프
# 36. 날씨의 아이
# 37. 프렌치 디스패치
# 38. 3000년의 기다림
# 39. 별을 쫓는 아이
# 40. 사랑할 땐 누구나 최악이 된다
# 41. 더 메뉴
# 42. 그린 나이트
# 43. 젠틀맨
# 44. 원피스 필름 레드

# %%
# 네이버 영화 평점 순위
URL = 'https://movie.naver.com/movie/sdb/rank/rmovie.naver?sel=cur&date=20230115'
res = requests.get(URL, headers = {'User-Agent':'Mozilla/5.0'})
html = res.text
soup = BeautifulSoup(html, 'html.parser')
rank = 1
movie = []
rank = []

for i in soup.select('div[class=tit5]'):
    
    movie.append(i.text.strip())

for i in soup.select('td[class=point]'):
    rank_li.append(i.text.strip())

# %%
for i in range(len(movie)):
    print(i+1,movie[i],"/// 평점: ",rank_li[i])
# Out:
# 1 더 퍼스트 슬램덩크 /// 평점:  9.53
# 2 올빼미 /// 평점:  9.35
# 3 시네마 천국 /// 평점:  9.33
# 4 말할 수 없는 비밀 /// 평점:  9.27
# 5 극장판 주술회전 0 /// 평점:  9.22
# 6 킹 오브 프리즘 /// 평점:  9.18
# 7 코다 /// 평점:  9.14
# 8 러브레터 /// 평점:  9.13
# 9 킹 오브 프리즘 프라이드 더 히어로 /// 평점:  9.11
# 10 탄생 /// 평점:  9.09
# 11 비긴 어게인 /// 평점:  9.04
# 12 타오르는 여인의 초상 /// 평점:  9.03
# 13 영웅 /// 평점:  9.02
# 14 더 파더 /// 평점:  9.00
# 15 윤희에게 /// 평점:  8.95
# 16 장화신은 고양이: 끝내주는 모험 /// 평점:  8.82
# 17 너의 이름은. /// 평점:  8.81
# 18 벌새 /// 평점:  8.74
# 19 마미 /// 평점:  8.67
# 20 헤어질 결심 /// 평점:  8.65
# 21 아바타: 물의 길 /// 평점:  8.64
# 22 라라랜드 /// 평점:  8.63
# 23 오늘 밤, 세계에서 이 사랑이 사라진다 해도 /// 평점:  8.57
# 24 양자경의 더 모든 날 모든 순간 /// 평점:  8.49
# 25 스위치 /// 평점:  8.47
# 26 레토 /// 평점:  8.43
# 27 드라이브 마이 카 /// 평점:  8.43
# 28 라 비 앙 로즈 /// 평점:  8.39
# 29 패터슨 /// 평점:  8.29
# 30 에브리씽 에브리웨어 올 앳 원스 /// 평점:  8.24
# 31 거북이는 의외로 빨리 헤엄친다 /// 평점:  8.22
# 32 애프터 양 /// 평점:  8.20
# 33 우연과 상상 /// 평점:  8.14
# 34 본즈 앤 올 /// 평점:  8.12
# 35 원더풀 라이프 /// 평점:  8.01
# 36 날씨의 아이 /// 평점:  7.97
# ...
