# %%
import requests as requests
from bs4 import BeautifulSoup

# %%
# 네이버 뉴스 속보
URL ='https://news.naver.com/main/list.nhn'
res = requests.get(URL, headers = {'User-Agent':'Mozilla/5.0'})

# %%
html = res.text

# %%
soup = BeautifulSoup(html, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE HTML>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="600" http-equiv="refresh">
# <meta content="width=1106" name="viewport">
# <meta content="언론사별 속보 뉴스" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://news.naver.com/main/list.naver?mode=LSD&amp;mid=sec&amp;sid=" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" property="og:image">
# <meta content="언론사별 속보 뉴스를 제공합니다." property="og:description"/>
# <meta content="네이버" property="og:article:author">
# <meta content="summary" name="twitter:card"/>
# <meta content="언론사별 속보 뉴스" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="네이버 뉴스" name="twitter:creator"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" name="twitter:image"/>
# <meta content="언론사별 속보 뉴스를 제공합니다." name="twitter:description"/>
# <title>홈 : 네이버 뉴스	</title>
# <link href="https://ssl.pstatic.net/static.news/image/news/2014/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20221222_121517/css/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20221222_121517/css/news.css" rel="stylesheet" type="text/css"/>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20221222_121517/js/news.jindo.js" type="text/javascript"></script>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.news/pnews/resources/20221222_121517/js/news.jquery.js" type="text/javascript"></script>
# <script type="text/javascript">
# var _MAIN_NEWS_MENU_ID='sec';
# var _MAIN_NEWS_SECTION_ID='';
# var ccsrv='cc.naver.com';
# var g_ssc='news.flash';
# window.nsc = g_ssc;
# var gnb_service='news';
# var gnb_logout=encodeURIComponent(location.href);
# var gnb_template='gnb_utf8';
# var gnb_brightness = 3;
# var gnb_searchbox='on';
# var gnb_shortnick='on';
#
# var gnb_timestamp = "Tue Jan 17 09:56:05 KST 2023";
# </script>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20221222_121517/js/news.service.js" type="text/javascript"></script>
# <script>
#
#     var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";
#     if (!isUnderIE10) {
#         var gladSDK = document.createElement("script");
#         gladSDK.async = true;
#         gladSDK.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#         document.head.appendChild(gladSDK);
#     }
#
#
#     window.gladsdk = window.gladsdk || { cmd: [] };
#
#     window.gladsdk.cmd.push(function () {
#         window.gladsdk.setGlobalConfig({enablePersistAd: true});
#         window.gladsdk.setHostMeta('theme', 'system');
#
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newsend',
#             adSlotElementId: 'glad_ad_newsend'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newslist',
#             adSlotElementId: 'glad_ad_newslist'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_sidebox',
#             adSlotElementId: 'glad_ad_sidebox'
#         });
#     })
# </script>
# </meta></meta></meta></meta></head>
# <body>
# <div id="wrap">
# <!-- 광고적용 태그 추가 -->
# <div id="da_base"></div>
# <div id="da_stake"></div>
# <div class="header" id="header">
# <div id="u_skip">
# <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div class="snb_area">
# <div class="snb_inner">
# <div class="gnb_area">
# <div class="gnb_wrap">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="gnb_search is_hidden _search_content">
# </div>
# <div class="gnb_tool" id="gnb_search_tool">
# <a class="tool_button _search_content_toggle_btn nclicks(gnb.sch)" href="javascript:;"><span class="icon_search">검색</span></a>
# </div>
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="h_logo nclicks(gnb.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(gnb.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>
# <ul class="snb_related_service">
# <li><span class="snb_bdr"></span><a class="entertain nclicks(gnb.enter)" href="https://entertain.naver.com/home">TV연예</a></li>
# <li><span class="snb_bdr"></span><a class="sports nclicks(gnb.sports)" href="https://sports.news.naver.com">스포츠</a></li>
# <li><span class="snb_bdr"></span><a class="weather nclicks(gnb.weather)" href="https://weather.naver.com">날씨</a></li>
# <li><span class="snb_bdr"></span><a class="premium nclicks(gnb.premium)" href="https://contents.premium.naver.com">프리미엄</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lnb_area">
# <div class="lnb_inner">
# <div class="lnb_both">
# <div class="lnb_left">
# <div class="lnb_menu" id="lnb">
# <ul>
# <li><a class="nclicks(lnb.pcmedia)" href="/"><span class="tx">언론사별</span> </a></li>
# <li><a class="nclicks(lnb.pol)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="tx">정치</span> </a></li>
# <li><a class="nclicks(lnb.eco)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="tx">경제</span> </a></li>
# <li><a class="nclicks(lnb.soc)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="tx">사회</span> </a></li>
# <li><a class="nclicks(lnb.lif)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="tx">생활/문화</span> </a></li>
# <li><a class="nclicks(lnb.sci)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="tx">IT/과학</span> </a></li>
# <li><a class="nclicks(lnb.wor)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="tx">세계</span> </a></li>
# <li><a class="nclicks(lnb.rankin)" href="/main/ranking/popularDay.naver?mid=etc&amp;sid1=111"><span class="tx">랭킹</span> </a></li>
# <li><a class="nclicks(lnb.paper)" href="/newspaper/home"><span class="tx">신문보기</span> </a></li>
# <li><a class="nclicks(lnb.opi)" href="/opinion/home"><span class="tx">오피니언</span> </a></li>
# <li><a class="nclicks(lnb.tv)" href="/main/tv/index.naver?mid=tvh"><span class="tx">TV</span> </a></li>
# <li><a class="nclicks(lnb.fact)" href="/main/factcheck/main.naver"><span class="tx">팩트체크</span> </a></li>
# </ul>
# </div>
# </div>
# <div class="lnb_right">
# <div class="lnb_extra">
# <div class="lnb_extra_menu">
# <ul class="lnb_extra_menu_list">
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right3)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(STA.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right4)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="lnb">
# <span class="lnb_date"><strong>01</strong>.<strong>17</strong><span class="day">(화)</span></span>
# <ul class="lnb_side" tabindex="0">
# <li><a class="nclicks(slb.allmedia)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li><a class="nclicks(slb.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li><a class="nclicks(slb.library)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# <hr/>
# <table cellpadding="0" cellspacing="0" class="container">
# <caption class="blind">기사목록</caption>
# <colgroup>
# <col class="col_snb"/>
# <col class="col_content"/>
# <col class="col_aside"/>
# </colgroup>
# <tr>
# <td class="snb">
# <div class="snb" id="snb">
# <h2 class="h"><a class="nclicks(lmn_fla.home)" href="/main/list.naver?mode=LSD&amp;mid=sec&amp;sid1=001">속보</a></h2>
# <ul class="nav">
# <li><a class="snb_s nclicks(lmn_fla.pol)" href="/main/list.naver?mode=LSD&amp;mid=sec&amp;sid1=100">정치 </a></li>
# <li><a class="snb_s2 nclicks(lmn_fla.eco)" href="/main/list.naver?mode=LSD&amp;mid=sec&amp;sid1=101">경제 </a></li>
# <li><a class="snb_s3 nclicks(lmn_fla.soc)" href="/main/list.naver?mode=LSD&amp;mid=sec&amp;sid1=102">사회 </a></li>
# <li><a class="snb_s4 nclicks(lmn_fla.lif)" href="/main/list.naver?mode=LSD&amp;mid=sec&amp;sid1=103">생활/문화 </a></li>
# <li><a class="snb_s5 nclicks(lmn_fla.wor)" href="/main/list.naver?mode=LSD&amp;mid=sec&amp;sid1=104">세계 </a></li>
# <li><a class="snb_s6 nclicks(lmn_fla.sci)" href="/main/list.naver?mode=LSD&amp;mid=sec&amp;sid1=105">IT/과학 </a></li>
# <li><a class="snb_s9 nclicks(lmn_fla.col)" href="/main/list.naver?mode=LSD&amp;mid=sec&amp;sid1=110">오피니언 </a></li>
# <li><a class="snb_s10 nclicks(lmn_fla.yon)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y">연합뉴스 속보 </a></li>
# </ul>
# <div class="snb_banner">
# <a class="nclicks(lmn_fla.pmb,,1)" href="https://media.naver.com/channel/setting?back=main"><img alt="언론사 구독하기" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/01/14/142956425_144518244_%2525B8%2525F0%2525B9%2525D9%2525C0%2525CF%2525B8%2525DE%2525C0%2525CE.png" width="71"/></a>
# </div>
# <div class="snb_banner">
# <a class="nclicks(lmn_fla.pmb,,1)" href="https://contents.premium.naver.com/"><img alt="네이버 프리미엄콘텐츠" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/05/28/233112515_DA%2540PC%25B4%25BA%25BD%25BA%25C1%25C2%25C3%25F8.png" width="71"/></a>
# </div>
# </div>
# </td>
# <td class="content">
# <div class="content" id="main_content">
# <div class="list_header newsflash_header2">
# <h3> 속보</h3>
# <div class="topbox_type1">
# <div>
# <ul class="massmedia">
# <li><a class="on nclicks(cnt_press)" href="/main/list.naver?mode=LSD&amp;mid=sec&amp;sid1=">전체</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="list_body newsflash_body">
# <div class="newsflash_header3">
# <h3>전체</h3>
# <div class="view_type">
# <a class="newsp nclicks(fls.vtype)" href="list.naver;jsessionid=028F40D6F5A56A72F0C845F81B8AE27D?mode=LSD&amp;mid=sec&amp;listType=paper&amp;date=20230117" title="신문에 게재된 기사만 보실 수 있습니다.">신문게재기사만</a><span class="bar">|</span>
# <a class="tit_off nclicks(fls.vtype)" href="list.naver;jsessionid=028F40D6F5A56A72F0C845F81B8AE27D?mode=LSD&amp;mid=sec&amp;listType=title&amp;date=20230117">제목형</a>
# <a class="sum_on nclicks(fls.vtype)" href="list.naver;jsessionid=028F40D6F5A56A72F0C845F81B8AE27D?mode=LSD&amp;mid=sec&amp;listType=summary&amp;date=20230117">요약형</a>
# <a class="photo_off nclicks(fls.vtype)" href="list.naver;jsessionid=028F40D6F5A56A72F0C845F81B8AE27D?mode=LSD&amp;mid=sec&amp;listType=photo&amp;type=3&amp;date=20230117">포토만</a>
# </div>
# </div>
# <ul class="type06_headline">
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/023/0003740964">
# <img alt="혼자 먹다 둘이 먹었더니 건강해졌다… 노인들 ‘혼밥’ 위험한 이유" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/023/2023/01/17/3740964.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/023/0003740964">
# 								 혼자 먹다 둘이 먹었더니 건강해졌다… 노인들 ‘혼밥’ 위험한 이유
# 								</a>
# </dt>
# <dd>
# <span class="lede">‘혼밥’(혼자 밥 먹기)이 잦은 노인이라면 훨씬 더 빨리 노쇠해진다는 연구 결과가 나왔다. 삼성서울병원 가정의학과(송윤미 교수· …</span>
# <span class="writing">조선일보</span>
# <span class="date is_new">1분전</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/014/0004956510">
# <img alt="동양철관, 급여 끝전 모아 지역사회 나눔 실천" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/014/2023/01/17/4956510.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/014/0004956510">
# 								 동양철관, 급여 끝전 모아 지역사회 나눔 실천
# 								</a>
# </dt>
# <dd>
# <span class="lede">동양철관이 지난 16일 소외된 이웃을 위해 임직원들이 급여 우수리를 모아 마련한 성금을 천안시복지재단에 기탁했다고 17일 밝혔다 …</span>
# <span class="writing">파이낸셜뉴스</span>
# <span class="date is_new">1분전</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/119/0002676060">
# <img alt="천장 균열에도 영업한 NC 백화점 야탑점, 무기한 영업 중단" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/119/2023/01/17/2676060.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/119/0002676060">
# 								 천장 균열에도 영업한 NC 백화점 야탑점, 무기한 영업 중단
# 								</a>
# </dt>
# <dd>
# <span class="lede">천장 균열 상태에서 영업을 지속해 논란이 된 NC 백화점 야탑점이 영업을 중단하고 정밀 안전점검에 들어가기로 했다. NC 백화점 …</span>
# <span class="writing">데일리안</span>
# <span class="date is_new">1분전</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/079/0003728245">
# <img alt='[돌쇠토론]"나경원, 尹압박 못 견뎌" vs "꺾이면 정치인생 끝"' height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/079/2023/01/17/3728245.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/079/0003728245">
# 								 [돌쇠토론]"나경원, 尹압박 못 견뎌" vs "꺾이면 정치인생 끝"
# 								</a>
# </dt>
# <dd>
# <span class="lede">■ 방송 : CBS 라디오 &lt;김현정의 뉴스쇼&gt; FM 98.1 (07:20~09:00) ■ 진행 : 김현정 앵커 ■ 대담 : 박원 …</span>
# <span class="writing">노컷뉴스</span>
# <span class="date is_new">1분전</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/016/0002091742">
# <img alt="호텔신라 ‘맛제주’ 식당 주인들, 따뜻한 이불 나눔 실천" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/016/2023/01/17/2091742.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/016/0002091742">
# 								 호텔신라 ‘맛제주’ 식당 주인들, 따뜻한 이불 나눔 실천
# 								</a>
# </dt>
# <dd>
# <span class="lede">호텔신라는 ‘맛있는 제주 만들기(맛제주)’를 통해 재기에 성공한 식당 주인들이 소외이웃을 위한 이불 100채를 전달했다고 17일 …</span>
# <span class="writing">헤럴드경제</span>
# <span class="date is_new">1분전</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/047/0002379363">
# <img alt='"수확 한 달 남은 벼 갈아 엎길래..." 송전탑 반대 농민들 최후진술' height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/047/2023/01/17/2379363.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/047/0002379363">
# 								 "수확 한 달 남은 벼 갈아 엎길래..." 송전탑 반대 농민들 최후진술
# 								</a>
# </dt>
# <dd>
# <span class="lede">삽교호 인근 한전 철탑공사 막아서... 검찰 벌금 구형에 선처 호소 ▲ 지난 2021년 7월 12일 조 아무개씨가 벼를 갈아 엎 …</span>
# <span class="writing">오마이뉴스</span>
# <span class="date is_new">1분전</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/119/0002676059">
# <img alt="작년 증시 부진에 주식결제대금 전년比 26.5%↓" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/119/2023/01/17/2676059.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/119/0002676059">
# 								 작년 증시 부진에 주식결제대금 전년比 26.5%↓
# 								</a>
# </dt>
# <dd>
# <span class="lede">지난해 증시 부진으로 인해 주식결제대금이 대폭 줄어든 것으로 나타났다. 17일 한국예탁결제원에 따르면 2022년 주식결제대금 총 …</span>
# <span class="writing">데일리안</span>
# <span class="date is_new">1분전</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/030/0003073038">
# <img alt="테크트랜스, Non-BPA 친환경 코팅 기술 개발...캔 제조사와 기술 적용 협의" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/030/2023/01/17/3073038.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/030/0003073038">
# 								 테크트랜스, Non-BPA 친환경 코팅 기술 개발...캔 제조사와 기술 적용 협의
# 								</a>
# </dt>
# <dd>
# <span class="lede">친환경 코팅처리 전문기업 테크트랜스(대표 유재인)가 환경 호르몬이 발생하지 않는 캔 내부 코팅 기술을 개발, 캔 전문제조사와 제 …</span>
# <span class="writing">전자신문</span>
# <span class="date is_new">1분전</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/654/0000030243">
# <img alt='[속보] 이준석 "윤핵관, 당원들 성향 몰라....결선투표시 까무러칠 것"' height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/654/2023/01/17/30243.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/654/0000030243">
# 								 [속보] 이준석 "윤핵관, 당원들 성향 몰라....결선투표시 까무러칠 것"
# 								</a>
# </dt>
# <dd>
# <span class="lede">국민의힘 이준석 전 대표가 이번 전당대회 당대표 결선 투표 시 결과가 '윤핵관' 생각과 다른 결론이 날 것으로 예상했다. 이 같 …</span>
# <span class="writing">강원도민일보</span>
# <span class="date is_new">1분전</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/079/0003728244">
# <img alt="가출 청소년과 이틀 동안 숙박업소 머문 20대 2명 벌금" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/079/2023/01/17/3728244.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/079/0003728244">
# 								 가출 청소년과 이틀 동안 숙박업소 머문 20대 2명 벌금
# 								</a>
# </dt>
# <dd>
# <span class="lede">가출 청소년과 이틀 동안 숙박업소에서 함께 지낸 20대 남성 2명에게 벌금형이 선고됐다. 울산지법 형사3단독(판사 노서영)은 실 …</span>
# <span class="writing">노컷뉴스</span>
# <span class="date is_new">1분전</span>
# </dd>
# </dl>
# </li>
# </ul>
# <ul class="type06">
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/031/0000723077">
# <img alt="굿닥, 설 연휴 실시간 비대면 진료·운영…병원·약국 검색 서비스 강화" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/031/2023/01/17/723077.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/031/0000723077">
# 								 굿닥, 설 연휴 실시간 비대면 진료·운영…병원·약국 검색 서비스 강화
# 								</a>
# </dt>
# <dd>
# <span class="lede">국내 1위 헬스케어 플랫폼 굿닥이 설 명절 의료 서비스 강화에 나선다. 굿닥은 올해 설 연휴 기간 동안 ▲운영 중 병원·약국 검 …</span>
# <span class="writing">아이뉴스24</span>
# <span class="date is_new">1분전</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/666/0000001714">
# 								 [사설] ‘원톱 친윤’ 장제원의 도 넘는 오만·막말/수도권 민심, 尹정부에서 떠날 수 있다
# 								</a>
# </dt>
# <dd>
# <span class="lede">윤석열 대통령의 지지율이 다시 하락세로 돌아섰다. 심리적 경계선으로 불리는 40% 아래다. 리얼미터의 1월 2주 차 여론조사다. …</span>
# <span class="writing">경기일보</span>
# <span class="date is_new">1분전</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/008/0004841090">
# <img alt="[사진]수원지검 향하는 김성태 전 회장" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/008/2023/01/17/4841090.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/008/0004841090">
# 								 [사진]수원지검 향하는 김성태 전 회장
# 								</a>
# </dt>
# <dd>
# <span class="lede">해외 도피생활 중 태국에서 검거된 쌍방울그룹 김성태 전 회장과 양선길 현 회장이 17일 인천국제공항을 통해 압송되고 있다.</span>
# <span class="writing">머니투데이</span>
# <span class="date is_new">1분전</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/215/0001077779">
# <img alt="유동성 숨통 트인 롯데케미칼…주가도 이틀째 상승세" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/215/2023/01/17/1077779.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/215/0001077779">
# 								 유동성 숨통 트인 롯데케미칼…주가도 이틀째 상승세
# 								</a>
# </dt>
# <dd>
# <span class="lede">롯데케미칼이 비주력 계열사 매각으로 유동성 압박에서 벗어날 수 있다는 기대 속에 이틀째 상승세다. 17일 유가증권시장에서 롯데케 …</span>
# <span class="writing">한국경제TV</span>
# <span class="date is_new">1분전</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/421/0006580478">
# <img alt="경찰, '여성 사망' 도박장 운영 남성 2명 조사" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/421/2023/01/17/6580478.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/421/0006580478">
# 								 경찰, '여성 사망' 도박장 운영 남성 2명 조사
# 								</a>
# </dt>
# <dd>
# <span class="lede">원태성 박재하 기자 = 불법 도박장에서 경찰이 출동했다는 소리에 놀라 뛰어내린 여성이 사망한 사건과 관련해 경찰이 해당 도박장을 …</span>
# <span class="writing">뉴스1</span>
# <span class="date is_new">1분전</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/421/0006580477">
# <img alt="조폐공사 ‘K-Jump 2023’ 이벤트…300만원 이상 구매 시 사은품" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/421/2023/01/17/6580477.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/421/0006580477">
# 								 조폐공사 ‘K-Jump 2023’ 이벤트…300만원 이상 구매 시 사은품
# 								</a>
# </dt>
# <dd>
# <span class="lede">한국조폐공사가 31일까지 2023년 계묘년 토끼의 해를 맞아 ‘K-Jump 2023’ 이벤트를 진행한다. 17일 한국조폐공사에  …</span>
# <span class="writing">뉴스1</span>
# <span class="date is_new">1분전</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/277/0005206140">
# <img alt="[포토]스카이72 골프앤리조트 강제집행" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/277/2023/01/17/5206140.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/277/0005206140">
# 								 [포토]스카이72 골프앤리조트 강제집행
# 								</a>
# </dt>
# <dd>
# <span class="lede">17일 오전 인천시 중구 스카이72 골프앤리조트 앞에서 강제집행을 시도하려는 인천지법 집행관실 관계자들과 이를 막으려는 임차인  …</span>
# <span class="writing">아시아경제</span>
# <span class="date is_new">1분전</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/421/0006580476">
# <img alt="티몬-생어거스틴 '올인데이' 최대 53% 단독 특가 판매" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/421/2023/01/17/6580476.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/421/0006580476">
# 								 티몬-생어거스틴 '올인데이' 최대 53% 단독 특가 판매
# 								</a>
# </dt>
# <dd>
# <span class="lede">티몬은 단 하루 '티몬X생어거스틴 올인데이'를 열고 생어거스틴 금액권과 인기메뉴 간편식 등을 단독 최저가 판매한다고 17일 밝혔 …</span>
# <span class="writing">뉴스1</span>
# <span class="date is_new">1분전</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/123/0002295290">
# <img alt="bhc치킨,  ‘레드킹폭립’ 구매 인증 이벤트" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/123/2023/01/17/2295290.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/123/0002295290">
# 								 bhc치킨,  ‘레드킹폭립’ 구매 인증 이벤트
# 								</a>
# </dt>
# <dd>
# <span class="lede">bhc치킨은 신메뉴 ‘레드킹폭립’에 대한 관심과 설 명절을 맞아 행운선사하는 ‘행운 가득 bhc 폭! 주머니를 찾아라’ 이벤트를 …</span>
# <span class="writing">조세일보</span>
# <span class="date is_new">1분전</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/123/0002295289">
# <img alt="SK㈜ C&amp;C, 청년 장애인 ICT 전문가 육성…‘씨앗’ 교육생 모집" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/123/2023/01/17/2295289.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/123/0002295289">
# 								 SK㈜ C&amp;C, 청년 장애인 ICT 전문가 육성…‘씨앗’ 교육생 모집
# 								</a>
# </dt>
# <dd>
# <span class="lede">SK㈜ C&amp;C(사장 윤풍영)는 17일, 기업연합 채용연계형 청년 장애인 ICT 전문가 육성 프로그램인 ‘2023 씨앗(SIAT) …</span>
# <span class="writing">조세일보</span>
# <span class="date is_new">1분전</span>
# </dd>
# </dl>
# </li>
# </ul>
# </div>
# <div class="paging">
#
# <span class="lede">■ 방송 : CBS 라디오 &lt;김현정의 뉴스쇼&gt; FM 98.1 (07:20~09:00) ■ 진행 : 김현정 앵커 ■ 대담 : 박원 …</span>
# <span class="lede">호텔신라는 ‘맛있는 제주 만들기(맛제주)’를 통해 재기에 성공한 식당 주인들이 소외이웃을 위한 이불 100채를 전달했다고 17일 …</span>
# <span class="lede">삽교호 인근 한전 철탑공사 막아서... 검찰 벌금 구형에 선처 호소 ▲ 지난 2021년 7월 12일 조 아무개씨가 벼를 갈아 엎 …</span>
# <span class="lede">지난해 증시 부진으로 인해 주식결제대금이 대폭 줄어든 것으로 나타났다. 17일 한국예탁결제원에 따르면 2022년 주식결제대금 총 …</span>
# <span class="lede">친환경 코팅처리 전문기업 테크트랜스(대표 유재인)가 환경 호르몬이 발생하지 않는 캔 내부 코팅 기술을 개발, 캔 전문제조사와 제 …</span>
# <span class="lede">국민의힘 이준석 전 대표가 이번 전당대회 당대표 결선 투표 시 결과가 '윤핵관' 생각과 다른 결론이 날 것으로 예상했다. 이 같 …</span>
# <span class="lede">가출 청소년과 이틀 동안 숙박업소에서 함께 지낸 20대 남성 2명에게 벌금형이 선고됐다. 울산지법 형사3단독(판사 노서영)은 실 …</span>
# <span class="lede">국내 1위 헬스케어 플랫폼 굿닥이 설 명절 의료 서비스 강화에 나선다. 굿닥은 올해 설 연휴 기간 동안 ▲운영 중 병원·약국 검 …</span>
# <span class="lede">윤석열 대통령의 지지율이 다시 하락세로 돌아섰다. 심리적 경계선으로 불리는 40% 아래다. 리얼미터의 1월 2주 차 여론조사다. …</span>
# <span class="lede">해외 도피생활 중 태국에서 검거된 쌍방울그룹 김성태 전 회장과 양선길 현 회장이 17일 인천국제공항을 통해 압송되고 있다.</span>
# <span class="lede">롯데케미칼이 비주력 계열사 매각으로 유동성 압박에서 벗어날 수 있다는 기대 속에 이틀째 상승세다. 17일 유가증권시장에서 롯데케 …</span>
# <span class="lede">원태성 박재하 기자 = 불법 도박장에서 경찰이 출동했다는 소리에 놀라 뛰어내린 여성이 사망한 사건과 관련해 경찰이 해당 도박장을 …</span>
# <span class="lede">한국조폐공사가 31일까지 2023년 계묘년 토끼의 해를 맞아 ‘K-Jump 2023’ 이벤트를 진행한다. 17일 한국조폐공사에  …</span>
# <span class="lede">17일 오전 인천시 중구 스카이72 골프앤리조트 앞에서 강제집행을 시도하려는 인천지법 집행관실 관계자들과 이를 막으려는 임차인  …</span>
# <span class="lede">티몬은 단 하루 '티몬X생어거스틴 올인데이'를 열고 생어거스틴 금액권과 인기메뉴 간편식 등을 단독 최저가 판매한다고 17일 밝혔 …</span>
# <span class="lede">bhc치킨은 신메뉴 ‘레드킹폭립’에 대한 관심과 설 명절을 맞아 행운선사하는 ‘행운 가득 bhc 폭! 주머니를 찾아라’ 이벤트를 …</span>
# <span class="lede">SK㈜ C&amp;C(사장 윤풍영)는 17일, 기업연합 채용연계형 청년 장애인 ICT 전문가 육성 프로그램인 ‘2023 씨앗(SIAT) …</span>

# %%
# 네이버 영화 조회 순위
URL = 'https://movie.naver.com/movie/sdb/rank/rmovie.nhn'
res = requests.get(URL, headers = {'User-Agent':'Mozilla/5.0'})
html = res.text
soup = BeautifulSoup(html, 'html.parser')
rank = 1
for i in soup.select('div[class=tit3]'):
    
    print(str(rank)+". " + i.text.strip())
    rank += 1
# Out:
# 1. 더 퍼스트 슬램덩크
# 2. 아바타: 물의 길
# 3. 영웅
# 4. 젠틀맨
# 5. 스위치
# 6. 교섭
# 7. 유령
# 8. 올빼미
# 9. 강남좀비
# 10. 장화신은 고양이: 끝내주는 모험
# 11. 10일간의 애인
# 12. 문맨
# 13. 오늘 밤, 세계에서 이 사랑이 사라진다 해도
# 14. 3000년의 기다림
# 15. 메간
# 16. 솔캠
# 17. 라일 라일 크로커다일
# 18. 별 볼일 없는 인생
# 19. 시간을 꿈꾸는 소녀
# 20. 앤트맨과 와스프: 퀀텀매니아
# 21. 해시태그 시그네
# 22. 유랑의 달
# 23. 헤어질 결심
# 24. 바빌론
# 25. 더 메뉴
# 26. 에브리씽 에브리웨어 올 앳 원스
# 27. 압꾸정
# 28. 프린스 챠밍
# 29. 상견니
# 30. 늑대사냥
# 31. 극장판 카케구루이
# 32. 오펜하이머
# 33. 페일 블루 아이
# 34. 타이타닉: 25주년
# 35. 공조2: 인터내셔날
# 36. 탑건: 매버릭
# 37. 살수
# 38. 캐리와 슈퍼콜라
# 39. 보스 베이비 2
# 40. 신비아파트 극장판 차원도깨비와 7개의 세계
# 41. 나는 마을 방과후 교사입니다
# 42. 그 겨울, 나는
# 43. 마루이 비디오
# 44. 패닉 런
# 45. 헌트
# 46. 엄마의 땅: 그리샤와 숲의 주인
# 47. 인생은 아름다워
# 48. 토르: 러브 앤 썬더
# 49. 극장판 파워레인저 캡틴포스: 지구를 위한 싸움
# 50. 본즈 앤 올

# %%
# 네이버 영화 평점 순위
URL = 'https://movie.naver.com/movie/sdb/rank/rmovie.naver?sel=cur&date=20230115'
res = requests.get(URL, headers = {'User-Agent':'Mozilla/5.0'})
html = res.text
soup = BeautifulSoup(html, 'html.parser')
rank = 1
movie = []
rank_li = []

for i in soup.select('div[class=tit5]'):
    
    print(str(rank)+". " + i.text.strip())
    rank += 1
# Out:
# 1. 더 퍼스트 슬램덩크
# 2. 올빼미
# 3. 시네마 천국
# 4. 말할 수 없는 비밀
# 5. 극장판 주술회전 0
# 6. 킹 오브 프리즘
# 7. 코다
# 8. 러브레터
# 9. 킹 오브 프리즘 프라이드 더 히어로
# 10. 탄생
# 11. 비긴 어게인
# 12. 타오르는 여인의 초상
# 13. 영웅
# 14. 더 파더
# 15. 윤희에게
# 16. 장화신은 고양이: 끝내주는 모험
# 17. 너의 이름은.
# 18. 벌새
# 19. 마미
# 20. 헤어질 결심
# 21. 아바타: 물의 길
# 22. 라라랜드
# 23. 오늘 밤, 세계에서 이 사랑이 사라진다 해도
# 24. 양자경의 더 모든 날 모든 순간
# 25. 스위치
# 26. 레토
# 27. 드라이브 마이 카
# 28. 라 비 앙 로즈
# 29. 패터슨
# 30. 에브리씽 에브리웨어 올 앳 원스
# 31. 거북이는 의외로 빨리 헤엄친다
# 32. 애프터 양
# 33. 우연과 상상
# 34. 본즈 앤 올
# 35. 원더풀 라이프
# 36. 날씨의 아이
# 37. 프렌치 디스패치
# 38. 3000년의 기다림
# 39. 별을 쫓는 아이
# 40. 사랑할 땐 누구나 최악이 된다
# 41. 더 메뉴
# 42. 그린 나이트
# 43. 젠틀맨
# 44. 원피스 필름 레드

# %%
# 네이버 영화 평점 순위
URL = 'https://movie.naver.com/movie/sdb/rank/rmovie.naver?sel=cur&date=20230115'
res = requests.get(URL, headers = {'User-Agent':'Mozilla/5.0'})
html = res.text
soup = BeautifulSoup(html, 'html.parser')
rank = 1
movie = []
rank = []

for i in soup.select('div[class=tit5]'):
    
    movie.append(i.text.strip())

for i in soup.select('td[class=point]'):
    rank_li.append(i.text.strip())

# %%
for i in range(len(movie)):
    print(i+1,movie[i],"/// 평점:",rank_li[i])
# Out:
# 1 더 퍼스트 슬램덩크 /// 평점: 9.53
# 2 올빼미 /// 평점: 9.35
# 3 시네마 천국 /// 평점: 9.33
# 4 말할 수 없는 비밀 /// 평점: 9.27
# 5 극장판 주술회전 0 /// 평점: 9.22
# 6 킹 오브 프리즘 /// 평점: 9.18
# 7 코다 /// 평점: 9.14
# 8 러브레터 /// 평점: 9.13
# 9 킹 오브 프리즘 프라이드 더 히어로 /// 평점: 9.11
# 10 탄생 /// 평점: 9.09
# 11 비긴 어게인 /// 평점: 9.04
# 12 타오르는 여인의 초상 /// 평점: 9.03
# 13 영웅 /// 평점: 9.02
# 14 더 파더 /// 평점: 9.00
# 15 윤희에게 /// 평점: 8.95
# 16 장화신은 고양이: 끝내주는 모험 /// 평점: 8.82
# 17 너의 이름은. /// 평점: 8.81
# 18 벌새 /// 평점: 8.74
# 19 마미 /// 평점: 8.67
# 20 헤어질 결심 /// 평점: 8.65
# 21 아바타: 물의 길 /// 평점: 8.64
# 22 라라랜드 /// 평점: 8.63
# 23 오늘 밤, 세계에서 이 사랑이 사라진다 해도 /// 평점: 8.57
# 24 양자경의 더 모든 날 모든 순간 /// 평점: 8.49
# 25 스위치 /// 평점: 8.47
# 26 레토 /// 평점: 8.43
# 27 드라이브 마이 카 /// 평점: 8.43
# 28 라 비 앙 로즈 /// 평점: 8.39
# 29 패터슨 /// 평점: 8.29
# 30 에브리씽 에브리웨어 올 앳 원스 /// 평점: 8.24
# 31 거북이는 의외로 빨리 헤엄친다 /// 평점: 8.22
# 32 애프터 양 /// 평점: 8.20
# 33 우연과 상상 /// 평점: 8.14
# 34 본즈 앤 올 /// 평점: 8.12
# 35 원더풀 라이프 /// 평점: 8.01
# 36 날씨의 아이 /// 평점: 7.97
# 37 프렌치 디스패치 /// 평점: 7.96
# 38 3000년의 기다림 /// 평점: 7.94
# 39 별을 쫓는 아이 /// 평점: 7.90
# 40 사랑할 땐 누구나 최악이 된다 /// 평점: 7.73
# 41 더 메뉴 /// 평점: 7.25
# 42 그린 나이트 /// 평점: 7.24
# 43 젠틀맨 /// 평점: 6.89
# 44 원피스 필름 레드 /// 평점: 6.85
